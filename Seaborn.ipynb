# %% [markdown]
# # Seaborn:
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive statistical graphics. Seaborn is particularly useful for creating informative and visually appealing statistical graphics. It builds on top of matplotlib and integrates closely with pandas data structures.
#
# Seaborn simplifies the process of creating complex visualizations such as scatter plots, bar plots, box plots, histograms, heatmaps, and more. It also offers built-in themes and color palettes to enhance the aesthetics of the plots. Seaborn is often preferred for its ease of use and its ability to generate visually appealing plots with relatively little code.

# %% [markdown]
# ## Import library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Dataset

# %% [markdown]
# data set is available in kaggle : https://www.kaggle.com/datasets/barkhaverma/placement-data-full-class

# %%
df = pd.read_csv("placementdata.csv")
df = df.drop(columns=["sl_no","hsc_b","ssc_b","salary"])
df
# Out:
#     gender  ssc_p  hsc_p     hsc_s  degree_p   degree_t workex  etest_p  \
# 0        M  67.00  91.00  Commerce     58.00   Sci&Tech     No     55.0
# 1        M  79.33  78.33   Science     77.48   Sci&Tech    Yes     86.5
# 2        M  65.00  68.00      Arts     64.00  Comm&Mgmt     No     75.0
# 3        M  56.00  52.00   Science     52.00   Sci&Tech     No     66.0
# 4        M  85.80  73.60  Commerce     73.30  Comm&Mgmt     No     96.8
# ..     ...    ...    ...       ...       ...        ...    ...      ...
# 210      M  80.60  82.00  Commerce     77.60  Comm&Mgmt     No     91.0
# 211      M  58.00  60.00   Science     72.00   Sci&Tech     No     74.0
# 212      M  67.00  67.00  Commerce     73.00  Comm&Mgmt    Yes     59.0
# 213      F  74.00  66.00  Commerce     58.00  Comm&Mgmt     No     70.0
# 214      M  62.00  58.00   Science     53.00  Comm&Mgmt     No     89.0
#
#     specialisation  mba_p      status
# 0           Mkt&HR  58.80      Placed
# ...

# %% [markdown]
# ## plots:
#
# Seaborn implements two types of functions, figure-level and axes-level, to provide users with flexibility, convenience, and control over the plotting process.
#
# **Figure-Level Function:**
#
# - Figure-level functions in Seaborn, such as `sns.catplot()` and `sns.relplot()`, create entire figures or grids of plots.
# - These functions typically involve creating a new figure or grid and then plotting multiple axes or subplots within that figure or grid.
# - They offer high-level control over the overall structure and layout of the plots, such as arranging multiple subplots in a grid or creating facets based on categorical variables.
# - Figure-level functions are useful for creating complex visualizations involving multiple subplots or facets, as they provide convenient ways to manage the overall layout and structure of the plots.
#
# **Axes-Level Function:**
#
# - Axes-level functions in Seaborn, such as `sns.scatterplot()` and `sns.barplot()`, create individual plots on a specific set of axes within an existing figure.
# - These functions typically involve plotting data on an existing set of axes, allowing for fine-grained control over the appearance and customization of the plot.
# - They offer low-level control over the properties of the individual plot elements, such as colors, markers, and axis labels.
# - Axes-level functions are useful for customizing the appearance and behavior of individual plots, as they allow for direct manipulation of the axes and plot elements.
#
# In simple terms, figure-level functions are used to create entire figures or grids of plots, while axes-level functions are used to create individual plots on specific sets of axes within those figures or grids. Figure-level functions provide high-level control over the overall layout and structure of the plots, while axes-level functions provide low-level control over the appearance and customization of individual plots.

# %% [markdown]
# <b>Relative merits of figure-level functions</b></br>
#
# Advantages:</br>
# * Easy faceting by data variables</br>
# * Legend outside of plot by default</br>
# * Easy figure-level customization</br>
# * Different figure size parameterization</br>
# </br>
# Drawbacks:</br>
# * Many parameters not in function signature</br>
# * Cannot be part of a larger matplotlib figure</br>
# * Different API from matplotlib</br>
# * Different figure size parameterization</br>

# %% [markdown]
# <span style="color:red">Note:</span>
# <span style="color:red">I have written both axis-level and figure-level functions for drawing the same plot. The code for axis-level functions has been commented out. Both approaches will generate identical plots.</span>

# %% [markdown]
# ## 1.) Relational Plot:
# * Relational plot is used to see the relation between 2 or more variables.
# * Bivariate Analysis

# %% [markdown]
# ## 1.a) Scatter Plot:
#
# A scatter plot is a type of data visualization that displays the relationship between two numerical variables. It is composed of individual data points, where each point represents the value of both variables. The position of each point on the plot corresponds to the values of the two variables, with one variable plotted along the x-axis and the other along the y-axis.
#
# **Definition:**
# A scatter plot is a graphical representation of the relationship between two continuous variables. It is commonly used to visualize patterns, trends, and correlations between variables.
#
# **When to use:**
# - **Exploring Relationships:** Scatter plots are useful for exploring the relationship between two variables, such as determining if there is a linear or nonlinear association between them.
# - **Identifying Patterns:** They help in identifying patterns, clusters, or outliers within the data.
# - **Assessing Correlation:** Scatter plots are often used to assess the strength and direction of the correlation between variables.
# - **Visualizing Distribution:** They provide a visual representation of the distribution of data points across the range of both variables.

# %%
# Figure level function
sns.relplot(data=df, x="ssc_p", y="hsc_p", hue="degree_t", style="status", kind="scatter")
plt.show()

# Axes-level function
# ax = sns.scatterplot(data=df, x="ssc_p", y="hsc_p", hue="degree_t", style="status")
# plt.show()

# %%
# Figure level function
sns.relplot(data=df, x="hsc_p", y="ssc_p", size="mba_p", hue="status")
plt.show()

# Axes-level function
# ax = sns.scatterplot(data=df, x="hsc_p", y="ssc_p", size="mba_p", hue="status")
# plt.show()

# %% [markdown]
# ### <a href="https://seaborn.pydata.org/tutorial/properties.html"><b>To know more about Markers Property</b></a>

# %% [markdown]
# ### 1.b) Line Plot:
#
# A line plot, also known as a line chart, is a type of data visualization that displays data points connected by straight line segments. It is particularly useful for showing trends and changes over time or other continuous intervals.
#
# **Definition:**
# A line plot is a graphical representation of data in which individual data points are connected by straight line segments. It is commonly used to visualize trends, patterns, and changes over time or other continuous intervals.
#
# **When to use:**
# - **Showing Trends:** Line plots are ideal for showing trends and changes over time or other continuous intervals, making them suitable for time-series data.
# - **Comparing Multiple Data Series:** They allow for the comparison of multiple data series on the same plot, making it easy to identify patterns and relationships.
# - **Highlighting Patterns:** Line plots help in identifying patterns, cycles, and irregularities in data.
# - **Visualizing Progression:** They are effective for visualizing progression, growth, or decline of variables over time or other continuous intervals.

# %%
# Figure level function
sns.relplot(data=df, x=df.index, y="ssc_p", kind="line", height=5, aspect=2.5, hue="status")
plt.xlabel("index")  # To change xlabel of plot
plt.xticks(rotation="vertical")  # to move x_ticks verticle
plt.show()

# Axes-level function
# fig, ax = plt.subplots(figsize=(2.5*5, 5))
# sns.lineplot(data=df, x=df.index, y="ssc_p", hue="status", ax=ax)
# ax.set_xlabel("index")
# ax.tick_params(axis='x', rotation=90)  # Rotating x-axis labels vertically
# plt.show()

# %% [markdown]
# ## 2.) Distribution Plot

# %% [markdown]
# ## 2.a) Hist Plot:
#
# A histogram is a type of data visualization that represents the distribution of a continuous numerical variable by dividing the data into intervals called bins and displaying the frequency or count of data points within each bin as bars.
#
# **Definition:**
# A histogram is a graphical representation of the distribution of a continuous numerical variable. It consists of a series of adjacent rectangles, or bins, where the width of each bin represents the interval of the variable and the height represents the frequency or count of data points within that interval.
#
# **When to use:**
# - **Understanding Distribution:** Histograms are useful for understanding the distribution of data, including its central tendency, variability, and shape.
# - **Identifying Patterns:** They help in identifying patterns such as peaks, valleys, or clusters in the data distribution.
# - **Detecting Outliers:** Histograms can reveal the presence of outliers or unusual values in the dataset.
# - **Assessing Skewness and Kurtosis:** They provide visual cues for assessing skewness (asymmetry) and kurtosis (peakedness) of the data distribution.

# %%
# Figure level function
sns.displot(data=df, x="etest_p", kind="hist")
plt.show()

# Axes-level function
# fig, ax = plt.subplots()
# sns.histplot(data=df, x="etest_p", ax=ax)
# plt.show()

# %% [markdown]
# <hr/>

# %% [markdown]
# **Note:**
# <span style="color:red">If you don't explicitly create a figure and axes using `plt.subplots()`, Matplotlib will automatically create them for you when you plot using functions like `plt.plot()`, `plt.scatter()`, `plt.hist()`, etc.</span>
#
# <span style="color:red">For example, if you simply run `plt.plot(x, y)`, Matplotlib will create a default figure and a set of axes, and then plot the data `x` against `y` on those axes.</span>
#
# <span style="color:red">However, explicitly creating the figure and axes using `plt.subplots()` gives you more control over the layout and arrangement of your plots, especially when creating multiple subplots or when you want to customize the figure properties.</span>
#
# <span style="color:red">In summary, while it's not strictly necessary to use `plt.subplots()`, it's often a good practice, especially when you need more control over your plots or when creating complex layouts with multiple subplots.</span>

# %% [markdown]
# <hr/>

# %%
# Figure level function
sns.displot(data=df, x="degree_t", kind="hist")
plt.show()

# Axes-level function
# fig, ax = plt.subplots()
# sns.histplot(data=df, x="degree_t", ax=ax)
# plt.show()

# %% [markdown]
# ## 2.b) KDE plot:
#
# A KDE (Kernel Density Estimation) plot is a type of data visualization that estimates the probability density function of a continuous random variable. It represents the distribution of the data by smoothing out the histogram, providing a smooth curve that approximates the underlying probability density.
#
# **Definition:**
# A KDE plot is a graphical representation of the estimated probability density function of a continuous random variable. It is created by smoothing out the histogram of the data, typically using a kernel function, to provide a continuous curve that approximates the distribution of the data.
#
# **When to use:**
# - **Visualizing Distribution:** KDE plots are useful for visualizing the distribution of data, especially when the underlying distribution is not well-known or when the data is noisy.
# - **Comparing Distributions:** They allow for the comparison of multiple distributions on the same plot, making it easy to compare the shapes and spread of different datasets.
# - **Assessing Smoothness:** KDE plots provide a smooth representation of the data distribution, which can help in assessing the smoothness of the underlying distribution and identifying potential patterns or features.
# - **Identifying Peaks and Valleys:** They help in identifying peaks, valleys, and modes in the data distribution, providing insights into the central tendency and variability of the data.

# %%
# Figure level function
sns.displot(data=df, x="etest_p", kind="kde", hue="gender", fill=True)
plt.show()

# Axes-level function
# fig, ax = plt.subplots()
# sns.kdeplot(data=df, x="etest_p", hue="gender", fill=True, ax=ax)
# plt.show()

# %% [markdown]
# ## 2.c) Rug plot:
#
# A rug plot is a type of data visualization that displays the distribution of data points along a single axis. It is typically used in conjunction with other plots, such as histograms or KDE plots, to provide additional information about the density and distribution of data points.
#
# **Definition:**
# A rug plot is a graphical representation of the distribution of data points along a single axis. It consists of a series of marks, or "rugs," placed at the location of each data point along the axis. Each rug mark represents the presence of a data point at that location.
#
# **When to use:**
# - **Enhancing Other Plots:** Rug plots are often used in conjunction with other plots, such as histograms or KDE plots, to provide additional information about the density and distribution of data points.
# - **Visualizing Individual Data Points:** They help in visualizing individual data points and their distribution along the axis, providing insights into the density and spread of the data.
# - **Assessing Data Density:** Rug plots provide a visual representation of the density of data points at different locations along the axis, making it easy to identify regions of high or low density.
# - **Comparing Distributions:** They can be used to compare the distribution of data points across different groups or categories, especially when overlaid on other plots.

# %%
# Figure level function
sns.kdeplot(data=df, x="etest_p")
sns.rugplot(data=df, x="etest_p")  # Always use with another plot such as kde
plt.show()

# Axes-level function
# fig, ax = plt.subplots()
# sns.kdeplot(data=df, x="etest_p", ax=ax)
# sns.rugplot(data=df, x="etest_p", ax=ax)  # Always use with another plot such as kde
# plt.show()

# %% [markdown]
# ## 2.d) 2D HIstogram:
#
# A 2D histogram is a type of data visualization that represents the joint distribution of two numerical variables. It divides the data space into bins along two dimensions and displays the frequency or count of data points within each bin using a color scale or contour lines.
#
# **Definition:**
# A 2D histogram is a graphical representation of the joint distribution of two numerical variables. It divides the data space into a grid of rectangular bins along two dimensions, typically the x-axis and y-axis, and counts the number of data points falling within each bin. The count or frequency within each bin is then represented using a color scale or contour lines.
#
# **When to use:**
# - **Exploring Bivariate Relationships:** 2D histograms are useful for exploring the relationship between two variables and identifying patterns or trends in their joint distribution.
# - **Visualizing Density:** They provide a visual representation of the density of data points across the two-dimensional space, helping to identify regions of high or low density.
# - **Comparing Distributions:** They allow for the comparison of the joint distribution of two variables across different groups or categories, making it easy to identify differences or similarities.
# - **Detecting Correlation:** 2D histograms can help in visually assessing the correlation between two variables, especially when combined with additional visualization techniques such as scatter plots or regression lines.

# %%
# Figure level function
sns.displot(data=df, x="ssc_p", y="hsc_p", kind="hist")
plt.show()

# Axes-level function
# fig, ax = plt.subplots()
# sns.histplot(data=df, x="ssc_p", y="hsc_p", ax=ax)
# plt.show()

# %% [markdown]
# ## 2.e) Bivariate kde plot:
#
# A bivariate KDE (Kernel Density Estimation) plot is a type of data visualization that estimates the joint probability density function of two continuous random variables. It represents the distribution of the data in two dimensions by smoothing out the scatter plot, providing a smooth contour plot that approximates the underlying joint distribution.
#
# **Definition:**
# A bivariate KDE plot is a graphical representation of the estimated joint probability density function of two continuous random variables. It is created by smoothing out the scatter plot of the data points in two dimensions, typically using a kernel function, to provide a continuous contour plot that approximates the joint distribution of the variables.
#
# **When to use:**
# - **Visualizing Bivariate Distribution:** Bivariate KDE plots are useful for visualizing the joint distribution of two variables and identifying patterns or trends in their relationship.
# - **Comparing Distributions:** They allow for the comparison of the joint distribution of two variables across different groups or categories, making it easy to identify differences or similarities.
# - **Assessing Correlation:** Bivariate KDE plots can help in visually assessing the correlation between two variables, providing insights into the strength and direction of their relationship.
# - **Identifying Clusters:** They help in identifying clusters or regions of high density in the joint distribution, providing insights into the structure of the data.

# %%
# Figure level function
sns.displot(data=df, x="ssc_p", y="hsc_p", kind="kde", fill=True, cbar=True)
plt.show()

# Axes-level function
# fig, ax = plt.subplots()
# sns.kdeplot(data=df, x="ssc_p", y="hsc_p", fill=True, cbar=True, ax=ax)
# plt.show()

# %% [markdown]
# ## 3.) Matrix Plot

# %% [markdown]
# ## 3.a) Heatmap:
#
# A heatmap is a type of data visualization that represents the magnitude of a numerical variable as colors in a two-dimensional grid. It is particularly useful for visualizing the correlation or relationship between multiple variables in a dataset.
#
# **Definition:**
# A heatmap is a graphical representation of data where the individual values contained in a matrix are represented as colors. It is commonly used to visualize the correlation between variables in a dataset or to display the distribution of values across two categorical variables.
#
# **When to use:**
# - **Visualizing Correlation:** Heatmaps are commonly used to visualize the correlation between variables in a dataset. They provide a quick and intuitive way to identify patterns and relationships between variables.
# - **Identifying Patterns:** Heatmaps help in identifying patterns and clusters within the data, making it easier to detect areas of interest or anomalies.
# - **Comparing Variables:** They allow for the comparison of multiple variables simultaneously, making it easy to identify similarities or differences across the variables.
# - **Displaying Categorical Data:** Heatmaps can also be used to display the distribution of values across two categorical variables, such as frequency counts or proportions.

# %%
temp = df.pivot_table(index="degree_t",columns="gender",values="etest_p")
sns.heatmap(temp)
plt.show()

# %%
temp = df.pivot_table(index="degree_t",columns="gender",values="etest_p")
sns.heatmap(temp,annot=True,linewidth=2,cmap="viridis")
plt.show()

# %% [markdown]
# # Categorical Plot

# %% [markdown]
# ## 4.ai) Strip Plot:
#
# A strip plot is a type of data visualization that displays the distribution of a continuous variable along one axis and individual data points as dots. It is particularly useful for visualizing the spread of data and identifying outliers or clusters.
#
# **Definition:**
# A strip plot is a graphical representation of the distribution of a continuous variable, where individual data points are displayed as dots along one axis. The dots are evenly spaced along the axis, and their vertical position corresponds to the value of the variable. Strip plots are often combined with other visualizations, such as box plots or violin plots, to provide additional insights into the data distribution.
#
# **When to use:**
# - **Visualizing Distribution:** Strip plots are useful for visualizing the distribution of a continuous variable and identifying patterns or trends in the data.
# - **Detecting Outliers:** They help in identifying outliers or extreme values in the dataset by displaying individual data points.
# - **Comparing Groups:** Strip plots can be used to compare the distribution of a variable across different groups or categories, making it easy to identify differences or similarities.
# - **Exploring Relationships:** They are effective for exploring relationships between a continuous variable and one or more categorical variables, providing insights into how the variable varies across different groups.

# %%
# It adds Some Noise in each categorical value  hence value not seeing in a line
# ctegorical-Numerical
# when we increase jitter attribute value will spread more.
# Figure level function
sns.catplot(data=df, x="degree_t", y="ssc_p", kind="strip")
plt.show()

# Axes-level function
# fig, ax = plt.subplots()
# sns.stripplot(data=df, x="degree_t", y="ssc_p", ax=ax)
# plt.show()

# %%
# Figure level function
sns.catplot(data=df, x="degree_t", y="ssc_p", kind="strip", jitter=0.3)
plt.show()

# Axes-level function
# fig, ax = plt.subplots()
# sns.stripplot(data=df, x="degree_t", y="ssc_p", jitter=0.3, ax=ax)
# plt.show()

# %% [markdown]
# ## 4.aii) Swarm Plot:
#
# A swarm plot is a type of categorical scatter plot that displays the distribution of data points for one categorical variable along one axis and the values of a continuous variable along the other axis. It helps in visualizing the distribution of data points within each category while avoiding overlapping points.
#
# **Definition:**
# A swarm plot is a graphical representation of categorical data where individual data points are plotted along one axis based on their categories, and the values of a continuous variable are plotted along the other axis. Unlike traditional scatter plots, swarm plots adjust the position of data points within each category to avoid overlap, providing a clearer view of the distribution of data points.
#
# **When to use:**
# - **Visualizing Categorical Data:** Swarm plots are useful for visualizing the distribution of data points within each category of a categorical variable.
# - **Identifying Patterns:** They help in identifying patterns, clusters, or outliers within the data, making it easier to detect trends or irregularities.
# - **Comparing Groups:** Swarm plots can be used to compare the distribution of a continuous variable across different categories, allowing for visual comparisons between groups.
# - **Handling Overlapping Data:** They are particularly effective when dealing with datasets with a large number of data points or when overlap is a concern, as they adjust the position of data points to minimize overlap.

# %%
# Categorical-numerical
# Figure level function
sns.catplot(data=df, x="degree_t", y="ssc_p", kind="swarm")
plt.show()

# Axes-level function
# fig, ax = plt.subplots()
# sns.swarmplot(data=df, x="degree_t", y="ssc_p", ax=ax)
# plt.show()

# %% [markdown]
# ## 4.bi) Boxplot:
#
# A box plot, also known as a box-and-whisker plot, is a type of data visualization that displays the distribution of a continuous variable through its quartiles. It provides a visual summary of the central tendency, variability, and skewness of the data distribution, as well as the presence of outliers.
#
# **Definition:**
# A box plot is a graphical representation of the distribution of a continuous variable. It consists of a rectangular box, known as the interquartile range (IQR), which spans the first quartile (Q1) to the third quartile (Q3) of the data. A line within the box represents the median (Q2) of the data. Additionally, "whiskers" extend from the box to the minimum and maximum values within a specified range, typically 1.5 times the IQR. Outliers beyond this range are plotted individually as points.
#
# **When to use:**
# - **Visualizing Distribution:** Box plots are useful for visualizing the distribution of a continuous variable, providing insights into its central tendency, spread, and skewness.
# - **Comparing Groups:** They allow for the comparison of the distribution of a variable across different groups or categories, making it easy to identify differences or similarities.
# - **Identifying Outliers:** Box plots help in identifying outliers or extreme values in the dataset, which may indicate unusual behavior or measurement errors.
# - **Assessing Symmetry:** They provide a visual indication of the symmetry or skewness of the data distribution, based on the position of the median relative to the quartiles.

# %%
# Figure level function
sns.catplot(data=df, y="etest_p", kind="box")
plt.show()

# Axes-level function
# fig, ax = plt.subplots()
# sns.boxplot(data=df, y="etest_p", ax=ax)
# plt.show()

# %%
# Figure level function
sns.catplot(data=df, x="status", y="etest_p", kind="box")
plt.show()

# Axes-level function
# fig, ax = plt.subplots()
# sns.boxplot(data=df, x="status", y="etest_p", ax=ax)
# plt.show()

# %% [markdown]
# ## 4.bii) ViolinPlot:
#
# A violin plot is a type of data visualization that combines the features of a box plot and a kernel density plot. It displays the distribution of a continuous variable by depicting its probability density as a rotated kernel density plot on each side, resembling the shape of a violin.
#
# **Definition:**
# A violin plot is a graphical representation of the distribution of a continuous variable. It consists of a rotated kernel density plot on each side, representing the probability density of the data at different values. The width of the plot at each point corresponds to the density of data points, with wider sections indicating higher density.
#
# **When to use:**
# - **Visualizing Distribution:** Violin plots are useful for visualizing the distribution of a continuous variable, providing insights into its central tendency, spread, and multimodality.
# - **Comparing Groups:** They allow for the comparison of the distribution of a variable across different groups or categories, making it easy to identify differences or similarities.
# - **Assessing Skewness:** Violin plots provide a visual indication of the symmetry or skewness of the data distribution, based on the shape of the plot.
# - **Detecting Outliers:** They can help in identifying outliers or extreme values in the dataset, particularly in regions of low density.

# %%
# Figure level function
sns.catplot(data=df, x="status", y="etest_p", kind="violin")
plt.show()

# Axes-level function
# fig, ax = plt.subplots()
# sns.violinplot(data=df, x="status", y="etest_p", ax=ax)
# plt.show()

# %%
# Figure level function
sns.catplot(data=df, x="status", y="etest_p", kind="violin", hue="gender", split=True)
plt.show()

# Axes-level function
# fig, ax = plt.subplots()
# sns.violinplot(data=df, x="status", y="etest_p", hue="gender", split=True, ax=ax)
# plt.show()

# %% [markdown]
# ## 4.ci) Bar Plot:
#
# A bar plot is a type of data visualization that represents categorical data with rectangular bars, where the length or height of each bar corresponds to the frequency or proportion of data within each category. It is commonly used to display comparisons between different categories.
#
# **Definition:**
# A bar plot is a graphical representation of categorical data, where each category is represented by a rectangular bar whose length or height corresponds to the frequency, count, or proportion of data within that category. The bars are typically arranged along one axis, with categories displayed on the other axis.
#
# **When to use:**
# - **Comparing Categories:** Bar plots are useful for comparing the frequency or proportion of data within different categories, making it easy to identify patterns or trends.
# - **Visualizing Counts:** They provide a visual representation of the counts or frequencies of data points within each category, helping to understand the distribution of categorical data.
# - **Displaying Proportions:** Bar plots can be used to display proportions or percentages within each category, allowing for comparisons between groups of different sizes.
# - **Showing Trends:** They are effective for visualizing changes or trends in categorical data over time or other dimensions.

# %%
# use ci=None to remove error Bar
# by default estimator calculate average
# Figure level function
sns.catplot(data=df, x="degree_t", y="etest_p", kind="bar", estimator=np.std)
plt.show()

# Axes-level function
# fig, ax = plt.subplots()
# sns.barplot(data=df, x="degree_t", y="etest_p", estimator=np.std, ax=ax)
# plt.show()

# %%
# Figure level function
sns.catplot(data=df, x="degree_t", y="etest_p", kind="bar", hue="gender")
plt.show()

# Axes-level function
# fig, ax = plt.subplots()
# sns.barplot(data=df, x="degree_t", y="etest_p", hue="gender", ax=ax)
# plt.show()

# %% [markdown]
# ## 4.cii) point plot:
#
# A point plot is a type of data visualization that displays the central tendency of a continuous variable within different categories. It represents the mean or median of the variable as points along with error bars, indicating confidence intervals or standard deviations.
#
# **Definition:**
# A point plot is a graphical representation of the central tendency of a continuous variable within different categories. It typically displays the mean or median of the variable as points, with error bars representing confidence intervals or standard deviations. Point plots are useful for comparing the central tendency of the variable across categories.
#
# **When to use:**
# - **Comparing Central Tendency:** Point plots are useful for comparing the mean or median of a continuous variable across different categories, providing insights into differences or similarities.
# - **Visualizing Confidence Intervals:** They help in visualizing the uncertainty associated with the estimates of central tendency, with error bars indicating confidence intervals or standard deviations.
# - **Identifying Trends:** Point plots can reveal trends or patterns in the data, such as increasing or decreasing central tendency across categories.
# - **Highlighting Differences:** They are effective for highlighting differences in the central tendency of the variable between groups or categories, making it easy to identify significant findings.

# %%
# Figure level function
sns.catplot(data=df, x="status", y="etest_p", kind="point")
plt.show()

# Axes-level function
# fig, ax = plt.subplots()
# sns.pointplot(data=df, x="status", y="etest_p", ax=ax)
# plt.show()

# %% [markdown]
# ## 5.a) Regplot:
#
# A regression plot is a type of data visualization that displays the relationship between two continuous variables and fits a regression line to the data. It is commonly used to visualize the linear relationship between variables and to assess the strength and direction of the relationship.
#
# **Definition:**
# A regression plot is a graphical representation of the relationship between two continuous variables. It typically displays the data points as scatter points and fits a regression line, which represents the best-fit linear relationship between the variables. Regression plots are useful for visualizing the trend in the data and assessing the predictive power of the relationship.
#
# **When to use:**
# - **Visualizing Relationship:** Regression plots are useful for visualizing the linear relationship between two continuous variables, helping to assess the strength and direction of the relationship.
# - **Assessing Predictive Power:** They provide insights into the predictive power of the relationship between variables, with the regression line serving as a model for making predictions.
# - **Identifying Outliers:** Regression plots help in identifying outliers or unusual data points that may influence the relationship between variables.
# - **Model Validation:** They are effective for validating regression models and assessing their goodness-of-fit to the data.

# %%
# Figure level function
sns.lmplot(data=df, x="ssc_p", y="hsc_p")
plt.show()

# Axes-level function
# fig, ax = plt.subplots()
# sns.scatterplot(data=df, x="ssc_p", y="hsc_p", ax=ax)
# sns.regplot(data=df, x="ssc_p", y="hsc_p", scatter=False, ax=ax)
# plt.show()

# %%
sns.lmplot(data=df,x="ssc_p",y="hsc_p",hue="gender")
plt.show()

# %% [markdown]
# ## 5.b) Residplot:
#
# A residual plot is a type of data visualization used in regression analysis to assess the goodness-of-fit of a regression model. It displays the residuals, or the differences between observed and predicted values, against the independent variable(s) or the fitted values.
#
# **Definition:**
# A residual plot is a graphical representation of the residuals, which are the differences between the observed values and the predicted values obtained from a regression model. The residuals are plotted against the independent variable(s) or the fitted values from the model. Residual plots are useful for diagnosing potential issues with the regression model, such as heteroscedasticity, nonlinearity, or outliers.
#
# **When to use:**
# - **Assessing Model Assumptions:** Residual plots are used to assess whether the assumptions of the regression model, such as linearity and constant variance of residuals, are met.
# - **Detecting Patterns:** They help in detecting patterns or systematic errors in the residuals, such as nonlinearity or heteroscedasticity, which may indicate that the model is misspecified.
# - **Identifying Outliers:** Residual plots can reveal the presence of outliers or influential data points that may have a disproportionate impact on the model.
# - **Validating Model Fit:** They are used for validating the fit of the regression model to the data and identifying areas where the model may need improvement.

# %%
sns.residplot(data=df,x="ssc_p",y="hsc_p")
plt.show()

# %% [markdown]
# # 6.) Multiplot

# %% [markdown]
# ## 6.a) Facet Grid:
#
# A facet grid is a type of data visualization that allows for the creation of multiple plots or subplots arranged in a grid layout, with each plot representing a subset of the data based on one or more categorical variables.
#
# **Definition:**
# A facet grid is a graphical representation of data where multiple plots or subplots are arranged in a grid layout, typically based on one or more categorical variables. Each subplot represents a subset of the data corresponding to a unique combination of categorical values, allowing for comparisons between different groups or categories within the dataset.
#
# **When to use:**
# - **Comparing Categorical Variables:** Facet grids are useful for comparing the distribution or relationship between variables across different categories or groups within the dataset.
# - **Visualizing Multivariate Relationships:** They help in visualizing multivariate relationships by arranging plots based on combinations of categorical variables.
# - **Handling Large Datasets:** Facet grids are effective for visualizing large datasets by breaking them down into smaller, more manageable subsets.
# - **Identifying Patterns:** They can reveal patterns or trends within the data by providing a structured way to explore relationships between variables.

# %%
object = sns.FacetGrid(data=df,row="gender",col="status")
object.map(sns.scatterplot,"hsc_p","ssc_p")
plt.show()

# %% [markdown]
# ## 6.b) Pair Plot:
#
# A pair plot is a type of data visualization that displays pairwise relationships between multiple variables in a dataset. It consists of a grid of scatter plots, where each plot represents the relationship between two variables, and histograms or kernel density plots along the diagonal, which display the distribution of each variable.
#
# **Definition:**
# A pair plot is a graphical representation of pairwise relationships between multiple variables in a dataset. It displays scatter plots of each pair of variables against each other in a grid layout. Along the diagonal of the grid, histograms or kernel density plots are typically shown to represent the distribution of each variable.
#
# **When to use:**
# - **Exploring Relationships:** Pair plots are useful for exploring relationships between multiple variables in a dataset, providing insights into correlations, trends, and patterns.
# - **Identifying Outliers:** They help in identifying outliers or unusual observations by visualizing the distribution of data points across different combinations of variables.
# - **Comparing Variables:** Pair plots allow for the comparison of multiple variables simultaneously, making it easy to identify similarities or differences between them.
# - **Assessing Multicollinearity:** They can be used to assess multicollinearity by examining the strength and direction of relationships between variables.

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# ## 6.c) PairGrid:
#
# A pair grid is a type of data visualization that extends the concept of a pair plot by allowing for more customization and flexibility in the arrangement of pairwise plots. It enables the creation of a grid of subplots, with each subplot representing the relationship between two variables, and allows for the inclusion of additional plot types and annotations.
#
# **Definition:**
# A pair grid is a graphical representation of pairwise relationships between multiple variables in a dataset, similar to a pair plot. However, it offers more customization options by allowing users to specify the arrangement of subplots, the types of plots to be displayed, and additional annotations or overlays.
#
# **When to use:**
# - **Customization:** Pair grids are useful when customization of the pairwise plots is required, such as specifying the order of variables, customizing plot aesthetics, or including additional annotations.
# - **Complex Relationships:** They are effective for visualizing complex relationships between variables by arranging plots in a grid layout and allowing for the inclusion of different plot types, such as scatter plots, line plots, or kernel density plots.
# - **Comparing Groups:** Pair grids enable the comparison of pairwise relationships between variables across different groups or categories within the dataset by facetting the grid based on categorical variables.
# - **Visualizing Multivariate Data:** They help in visualizing multivariate data by providing a structured way to explore relationships between multiple variables and identify patterns or trends.

# %%
obj = sns.PairGrid(data=df)
obj.map_diag(sns.histplot)
obj.map_upper(sns.scatterplot)
obj.map_lower(sns.kdeplot)
plt.show()

# %%
var = ["etest_p","mba_p"]
obj2 = sns.PairGrid(data=df[var])
obj2.map_diag(sns.kdeplot)
obj2.map_offdiag(sns.scatterplot)
plt.show()

# %% [markdown]
# ## 7.a) Joint plot:
#
# A joint plot is a type of data visualization that displays the relationship between two variables along with their marginal distributions. It combines multiple plots, such as scatter plots, histograms, or kernel density plots, into a single visualization to provide insights into the joint and marginal distributions of the variables.
#
# **Definition:**
# A joint plot is a graphical representation of the relationship between two variables, typically using a scatter plot to show their joint distribution. In addition to the scatter plot, it also includes marginal plots along the axes to display the distribution of each variable individually, such as histograms or kernel density plots.
#
# **When to use:**
# - **Visualizing Relationships:** Joint plots are useful for visualizing the relationship between two variables and identifying patterns or trends in their joint distribution.
# - **Assessing Correlation:** They help in assessing the strength and direction of the correlation between variables by displaying the scatter plot of their joint distribution.
# - **Examining Marginal Distributions:** Joint plots provide insights into the marginal distributions of the variables by including histograms or kernel density plots along the axes.
# - **Detecting Outliers:** They can reveal the presence of outliers or unusual observations in the data by examining the scatter plot of the joint distribution.

# %%
sns.jointplot(data=df,x="hsc_p",y="ssc_p")
plt.show()

# %% [markdown]
# ## 7.b) JointGrid

# %%
obj3 = sns.JointGrid(data=df)
obj3.plot(sns.scatterplot,sns.histplot)
plt.show()
